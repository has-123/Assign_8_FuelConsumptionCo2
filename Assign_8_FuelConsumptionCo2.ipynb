# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
from sklearn import linear_model

# %%
data = pd.read_csv('/content/FuelConsumptionCo2.csv')  
data.head(5)
# Out:
#    MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0       2014  ACURA         ILX      COMPACT         2.0          4
# 1       2014  ACURA         ILX      COMPACT         2.4          4
# 2       2014  ACURA  ILX HYBRID      COMPACT         1.5          4
# 3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5          6
# 4       2014  ACURA     RDX AWD  SUV - SMALL         3.5          6
#
#   TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          AS5        Z                   9.9                  6.7
# 1           M6        Z                  11.2                  7.7
# 2          AV7        Z                   6.0                  5.8
# 3          AS6        Z                  12.7                  9.1
# 4          AS6        Z                  12.1                  8.7
#
#    FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                   8.5                        33           196
# 1                   9.6                        29           221
# 2                   5.9                        48           136
# 3                  11.1                        25           255
# 4                  10.6                        27           244

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067 entries, 0 to 1066
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   MODELYEAR                 1067 non-null   int64
#  1   MAKE                      1067 non-null   object
#  2   MODEL                     1067 non-null   object
#  3   VEHICLECLASS              1067 non-null   object
#  4   ENGINESIZE                1067 non-null   float64
#  5   CYLINDERS                 1067 non-null   int64
#  6   TRANSMISSION              1067 non-null   object
#  7   FUELTYPE                  1067 non-null   object
#  8   FUELCONSUMPTION_CITY      1067 non-null   float64
#  9   FUELCONSUMPTION_HWY       1067 non-null   float64
#  10  FUELCONSUMPTION_COMB      1067 non-null   float64
#  11  FUELCONSUMPTION_COMB_MPG  1067 non-null   int64
#  12  CO2EMISSIONS              1067 non-null   int64
# dtypes: float64(4), int64(4), object(5)
# memory usage: 108.5+ KB

# %%
data.shape
# Out:
# (1067, 13)

# %%
data.describe()
# Out:
#        MODELYEAR   ENGINESIZE    CYLINDERS  FUELCONSUMPTION_CITY  \
# count     1067.0  1067.000000  1067.000000           1067.000000
# mean      2014.0     3.346298     5.794752             13.296532
# std          0.0     1.415895     1.797447              4.101253
# min       2014.0     1.000000     3.000000              4.600000
# 25%       2014.0     2.000000     4.000000             10.250000
# 50%       2014.0     3.400000     6.000000             12.600000
# 75%       2014.0     4.300000     8.000000             15.550000
# max       2014.0     8.400000    12.000000             30.200000
#
#        FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  \
# count          1067.000000           1067.000000               1067.000000
# mean              9.474602             11.580881                 26.441425
# std               2.794510              3.485595                  7.468702
# min               4.900000              4.700000                 11.000000
# 25%               7.500000              9.000000                 21.000000
# 50%               8.800000             10.900000                 26.000000
# 75%              10.850000             13.350000                 31.000000
# max              20.500000             25.800000                 60.000000
#
#        CO2EMISSIONS
# count   1067.000000
# mean     256.228679
# std       63.372304
# min      108.000000
# 25%      207.000000
# 50%      251.000000
# 75%      294.000000
# max      488.000000

# %% [markdown]
# #Lets select some features that we want to use for regression.

# %%
cdf = data[['ENGINESIZE','CYLINDERS','FUELCONSUMPTION_CITY','FUELCONSUMPTION_HWY','FUELCONSUMPTION_COMB','CO2EMISSIONS']]
cdf.head(9)
# Out:
#    ENGINESIZE  CYLINDERS  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0         2.0          4                   9.9                  6.7
# 1         2.4          4                  11.2                  7.7
# 2         1.5          4                   6.0                  5.8
# 3         3.5          6                  12.7                  9.1
# 4         3.5          6                  12.1                  8.7
# 5         3.5          6                  11.9                  7.7
# 6         3.5          6                  11.8                  8.1
# 7         3.7          6                  12.8                  9.0
# 8         3.7          6                  13.4                  9.5
#
#    FUELCONSUMPTION_COMB  CO2EMISSIONS
# 0                   8.5           196
# 1                   9.6           221
# 2                   5.9           136
# 3                  11.1           255
# 4                  10.6           244
# 5                  10.0           230
# 6                  10.1           232
# 7                  11.1           255
# 8                  11.6           267

# %% [markdown]
# #Lets plot Emission values with respect to Engine size:

# %%
plt.scatter(cdf.ENGINESIZE, cdf.CO2EMISSIONS,  color='blue')
plt.xlabel("Engine size")
plt.ylabel("Emission")
plt.show()

# %% [markdown]
# #Multiple Regression Model

# %%
x  = cdf[['ENGINESIZE','CYLINDERS','FUELCONSUMPTION_COMB']].values
y = cdf[['CO2EMISSIONS']].values

# %%
from sklearn.linear_model import LinearRegression
lin_reg = linear_model.LinearRegression()
lin_reg.fit(x,y)
# Out:
# LinearRegression()

# %%
# predicting the accuracy score
from sklearn.metrics import mean_squared_error, r2_score
# y_pred & y_true

y_pred = lin_reg.predict(x)

r_score = r2_score(y,y_pred)
MSE = mean_squared_error(y,y_pred)

RMSE = np.sqrt(mean_squared_error(y,y_pred))

print('‘r2 socre is = ',r_score)
print('‘mean_sqrd_error is =',MSE )
print('‘root_mean_squared error of is =',RMSE)

a_0 =lin_reg.intercept_
a_1 = lin_reg.coef_[0]
a_2 = lin_reg.coef_

print('a_0 is = ',a_0)
print('a_1 is =',a_1 )
#print('a_2 is =',a_2 )
# Out:
# ‘r2 socre is =  0.8639967940584256
# ‘mean_sqrd_error is = 545.6836368455175
# ‘root_mean_squared error of is = 23.359872363639266
# a_0 is =  [65.22328417]
# a_1 is = [10.85524041  7.51622501  9.59563161]

# %%
cdf.corr()
# Out:
#                       ENGINESIZE  CYLINDERS  FUELCONSUMPTION_CITY  \
# ENGINESIZE              1.000000   0.934011              0.832225
# CYLINDERS               0.934011   1.000000              0.796473
# FUELCONSUMPTION_CITY    0.832225   0.796473              1.000000
# FUELCONSUMPTION_HWY     0.778746   0.724594              0.965718
# FUELCONSUMPTION_COMB    0.819482   0.776788              0.995542
# CO2EMISSIONS            0.874154   0.849685              0.898039
#
#                       FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  CO2EMISSIONS
# ENGINESIZE                       0.778746              0.819482      0.874154
# CYLINDERS                        0.724594              0.776788      0.849685
# FUELCONSUMPTION_CITY             0.965718              0.995542      0.898039
# FUELCONSUMPTION_HWY              1.000000              0.985804      0.861748
# FUELCONSUMPTION_COMB             0.985804              1.000000      0.892129
# CO2EMISSIONS                     0.861748              0.892129      1.000000

# %%
corr = cdf.corr()
corr.style.background_gradient(cmap='coolwarm')
# 'RdBu_r', 'BrBG_r', & PuOr_r are other good diverging colormaps
# Out:
# <style type="text/css">
# #T_8bdae_row0_col0, #T_8bdae_row1_col1, #T_8bdae_row2_col2, #T_8bdae_row3_col3, #T_8bdae_row4_col4, #T_8bdae_row5_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_8bdae_row0_col1 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_8bdae_row0_col2 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_8bdae_row0_col3 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_8bdae_row0_col4, #T_8bdae_row4_col1 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_8bdae_row0_col5 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_8bdae_row1_col0 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_8bdae_row1_col2, #T_8bdae_row1_col3, #T_8bdae_row1_col4, #T_8bdae_row1_col5, #T_8bdae_row3_col0, #T_8bdae_row3_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_8bdae_row2_col0 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_8bdae_row2_col1 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_8bdae_row2_col3 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_8bdae_row2_col4, #T_8bdae_row4_col2 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_8bdae_row2_col5 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_8bdae_row3_col2 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_8bdae_row3_col4 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_8bdae_row3_col5 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_8bdae_row4_col0 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_8bdae_row4_col3 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_8bdae_row4_col5 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_8bdae_row5_col0 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_8bdae_row5_col1 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_8bdae_row5_col2, #T_8bdae_row5_col3 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_8bdae_row5_col4 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# </style>
# <table id="T_8bdae_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >ENGINESIZE</th>
#       <th class="col_heading level0 col1" >CYLINDERS</th>
#       <th class="col_heading level0 col2" >FUELCONSUMPTION_CITY</th>
#       <th class="col_heading level0 col3" >FUELCONSUMPTION_HWY</th>
#       <th class="col_heading level0 col4" >FUELCONSUMPTION_COMB</th>
#       <th class="col_heading level0 col5" >CO2EMISSIONS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8bdae_level0_row0" class="row_heading level0 row0" >ENGINESIZE</th>
#       <td id="T_8bdae_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_8bdae_row0_col1" class="data row0 col1" >0.934011</td>
#       <td id="T_8bdae_row0_col2" class="data row0 col2" >0.832225</td>
#       <td id="T_8bdae_row0_col3" class="data row0 col3" >0.778746</td>
#       <td id="T_8bdae_row0_col4" class="data row0 col4" >0.819482</td>
#       <td id="T_8bdae_row0_col5" class="data row0 col5" >0.874154</td>
#     </tr>
#     <tr>
#       <th id="T_8bdae_level0_row1" class="row_heading level0 row1" >CYLINDERS</th>
#       <td id="T_8bdae_row1_col0" class="data row1 col0" >0.934011</td>
#       <td id="T_8bdae_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_8bdae_row1_col2" class="data row1 col2" >0.796473</td>
#       <td id="T_8bdae_row1_col3" class="data row1 col3" >0.724594</td>
#       <td id="T_8bdae_row1_col4" class="data row1 col4" >0.776788</td>
#       <td id="T_8bdae_row1_col5" class="data row1 col5" >0.849685</td>
#     </tr>
#     <tr>
#       <th id="T_8bdae_level0_row2" class="row_heading level0 row2" >FUELCONSUMPTION_CITY</th>
#       <td id="T_8bdae_row2_col0" class="data row2 col0" >0.832225</td>
#       <td id="T_8bdae_row2_col1" class="data row2 col1" >0.796473</td>
#       <td id="T_8bdae_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_8bdae_row2_col3" class="data row2 col3" >0.965718</td>
#       <td id="T_8bdae_row2_col4" class="data row2 col4" >0.995542</td>
#       <td id="T_8bdae_row2_col5" class="data row2 col5" >0.898039</td>
#     </tr>
#     <tr>
#       <th id="T_8bdae_level0_row3" class="row_heading level0 row3" >FUELCONSUMPTION_HWY</th>
#       <td id="T_8bdae_row3_col0" class="data row3 col0" >0.778746</td>
#       <td id="T_8bdae_row3_col1" class="data row3 col1" >0.724594</td>
#       <td id="T_8bdae_row3_col2" class="data row3 col2" >0.965718</td>
#       <td id="T_8bdae_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_8bdae_row3_col4" class="data row3 col4" >0.985804</td>
#       <td id="T_8bdae_row3_col5" class="data row3 col5" >0.861748</td>
#     </tr>
#     <tr>
#       <th id="T_8bdae_level0_row4" class="row_heading level0 row4" >FUELCONSUMPTION_COMB</th>
#       <td id="T_8bdae_row4_col0" class="data row4 col0" >0.819482</td>
#       <td id="T_8bdae_row4_col1" class="data row4 col1" >0.776788</td>
#       <td id="T_8bdae_row4_col2" class="data row4 col2" >0.995542</td>
#       <td id="T_8bdae_row4_col3" class="data row4 col3" >0.985804</td>
#       <td id="T_8bdae_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_8bdae_row4_col5" class="data row4 col5" >0.892129</td>
#     </tr>
#     <tr>
#       <th id="T_8bdae_level0_row5" class="row_heading level0 row5" >CO2EMISSIONS</th>
#       <td id="T_8bdae_row5_col0" class="data row5 col0" >0.874154</td>
#       <td id="T_8bdae_row5_col1" class="data row5 col1" >0.849685</td>
#       <td id="T_8bdae_row5_col2" class="data row5 col2" >0.898039</td>
#       <td id="T_8bdae_row5_col3" class="data row5 col3" >0.861748</td>
#       <td id="T_8bdae_row5_col4" class="data row5 col4" >0.892129</td>
#       <td id="T_8bdae_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
